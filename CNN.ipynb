# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhitaa2329/genAI1/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio

from google.colab import files

uploaded = files.upload()  # Opens a file upload dialog
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import numpy as np
import os

# Load the pretrained MobileNetV2 model
base_model = MobileNetV2(weights="imagenet")
print("✅ Pretrained MobileNetV2 model loaded successfully!")

# Function to classify an uploaded image
def classify_uploaded_image(image_path):
    if not os.path.exists(image_path):
        return "⚠️ File not found. Please upload an image first."

    img = image.load_img(image_path, target_size=(224, 224))  # Load and resize image
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess for MobileNetV2

    predictions = base_model.predict(img_array)  # Get predictions
    decoded_predictions = decode_predictions(predictions, top=3)[0]  # Decode top 3 results

    return {label: float(prob) for (_, label, prob) in decoded_predictions}  # Convert to dictionary

# Example usage (Change 'my_image.jpg' to the actual filename you uploaded)
image_path = "/content/my_image.jpg"  # Change this to your uploaded image file
results = classify_uploaded_image(image_path)
print("🔍 Classification Results:", results)
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import numpy as np
import os

# Load the pretrained MobileNetV2 model
base_model = MobileNetV2(weights="imagenet")
print("✅ Pretrained MobileNetV2 model loaded successfully!")

# Function to classify an uploaded image
def classify_uploaded_image(image_path):
    if not os.path.exists(image_path):
        return "⚠️ File not found. Please upload an image first."

    img = image.load_img(image_path, target_size=(224, 224))  # Load and resize image
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess for MobileNetV2

    predictions = base_model.predict(img_array)  # Get predictions
    decoded_predictions = decode_predictions(predictions, top=3)[0]  # Decode top 3 results

    return {label: float(prob) for (_, label, prob) in decoded_predictions}  # Convert to dictionary

# Example usage (Change 'my_image.jpg' to the actual filename you uploaded)
image_path = "/content/my_image.jpg"  # Change this to your uploaded image file
results = classify_uploaded_image(image_path)
print("🔍 Classification Results:", results)
import gradio as gr

def classify_image(img):
    img = img.resize((224, 224))  # Resize image
    img_array = image.img_to_array(img)  # Convert to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess for MobileNetV2

    predictions = base_model.predict(img_array)  # Get predictions
    decoded_predictions = decode_predictions(predictions, top=3)[0]  # Decode top 3 results

    return {label: float(prob) for (_, label, prob) in decoded_predictions}  # Convert to dictionary

# Create Gradio interface
interface = gr.Interface(
    fn=classify_image,
    inputs=gr.Image(type="pil"),
    outputs=gr.Label(num_top_classes=3),
    title="Upload Your Image for Classification",
    description="Upload an image to classify using a pretrained MobileNetV2 model."
)

# Launch Gradio UI
interface.launch(share=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 4.1 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-b64b99cb-b6fd-48c5-b72c-b96d25c66888" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b64b99cb-b6fd-48c5-b72c-b96d25c66888">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# ...
